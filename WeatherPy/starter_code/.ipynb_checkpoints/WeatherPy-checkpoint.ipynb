# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities info
lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Make a Dataframe for city/country data
city_loc = pd.DataFrame({"City": cities, "Country": countries})
city_loc = city_loc.reset_index(drop=True)
city_loc.head()

# add columns to store the rest of the desired data
city_loc["Cloudiness"] = ""
city_loc["Humidity"] = ""
city_loc["Date"] = ""
city_loc["Max Temp"] = ""
city_loc["Wind Speed"] = ""

# Print the city count to confirm sufficient count
len(cities)

# %%
# Make a Dataframe for coordinates
city_coord = pd.DataFrame()
city_coord = city_coord.append(pd.DataFrame.from_dict({ "Latitude": lats, "Longitude": lngs}))   
city_coord

# Merge city dataframe and coordinates dataframe
data_merge = [city_loc, city_coord]
city_data = pd.concat([city_loc, city_coord], axis=1)
city_data = city_data.drop_duplicates()
city_data = city_data.dropna()
city_data = city_data.reset_index(drop=True)
city_data = pd.DataFrame(city_data)
city_data.head(10)
# Out:
#               City Country Cloudiness Humidity Date Max Temp Wind Speed  \
# 0          xambioa      br
# 1           albany      au
# 2             hilo      us
# 3          qaanaaq      gl
# 4      providencia      mx
# 5          rikitea      pf
# 6            mendi      pg
# 7  arraial do cabo      br
# 8       chokurdakh      ru
# 9       moses lake      us
#
#     Latitude   Longitude
# 0  -6.392484  -48.446189
# 1 -86.561001  103.671102
# 2  13.735470 -134.892095
# 3  89.756644  -92.641040
# 4 -89.000979  116.523222
# 5  29.399866 -111.919400
# 6 -25.183302 -136.252065
# 7  76.304423  -84.721604
# 8  -6.865364  143.053131
# 9 -45.054363  -27.645139

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# pulling website with API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Make request and store response
response = requests.get(f"{url}&q={city}").json()
response
# Out:
# {'coord': {'lon': -48.54, 'lat': -6.41},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 85.8,
#   'feels_like': 91.06,
#   'temp_min': 85.8,
#   'temp_max': 85.8,
#   'pressure': 1014,
#   'humidity': 64,
#   'sea_level': 1014,
#   'grnd_level': 1000},
#  'wind': {'speed': 6.24, 'deg': 109},
#  'clouds': {'all': 100},
#  'dt': 1588257728,
#  'sys': {'country': 'BR', 'sunrise': 1588238078, 'sunset': 1588280868},
#  'timezone': -10800,
#  'id': 3384940,
#  'name': 'Xambioá',
#  'cod': 200}

# %%
# create lists for data columns and a counter number of calls
city_names = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
record = 0

# Loop through the list of cities and perform a request for data on each
print(f"Beginning Data Retrieval")
for city in cities:
    try:
        response = requests.get(f"{url}&q={city}").json()
        city_names.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        city_record = (response['name'])
        record += 1
        print(f"The weather API responded with:# {record} : {city_record}")
        time.sleep(1)
    
    except KeyError: 
        print("City Skipped: Data Missing")
        
print("------------------------")
print("Data Retrieval Complete")
print("------------------------")
# Out:
# Beginning Data Retrieval
# The weather API responded with:# 1 : Xambioá
# The weather API responded with:# 2 : Albany
# The weather API responded with:# 3 : Hilo
# The weather API responded with:# 4 : Qaanaaq
# The weather API responded with:# 5 : La Providencia
# The weather API responded with:# 6 : Rikitea
# The weather API responded with:# 7 : Mendi
# The weather API responded with:# 8 : Arraial do Cabo
# The weather API responded with:# 9 : Chokurdakh
# The weather API responded with:# 10 : Moses Lake
# The weather API responded with:# 11 : Pangnirtung
# The weather API responded with:# 12 : Touros
# The weather API responded with:# 13 : Jamestown
# The weather API responded with:# 14 : Atuona
# The weather API responded with:# 15 : Tromsø
# City Skipped: Data Missing
# The weather API responded with:# 16 : Saint-Philippe
# The weather API responded with:# 17 : East London
# The weather API responded with:# 18 : Fougères
# The weather API responded with:# 19 : Pangody
# City Skipped: Data Missing
# The weather API responded with:# 20 : Vaini
# The weather API responded with:# 21 : Ushuaia
# The weather API responded with:# 22 : Yellowknife
# The weather API responded with:# 23 : Bonavista
# The weather API responded with:# 24 : Piranhas
# The weather API responded with:# 25 : St. George's
# The weather API responded with:# 26 : Vila Velha
# The weather API responded with:# 27 : Bluff
# City Skipped: Data Missing
# The weather API responded with:# 28 : Bathsheba
# The weather API responded with:# 29 : Hamilton
# The weather API responded with:# 30 : Bandarbeyla
# The weather API responded with:# 31 : Hobart
# The weather API responded with:# 32 : Mataura
# The weather API responded with:# 33 : Codrington
# The weather API responded with:# 34 : Punta Arenas
# The weather API responded with:# 35 : Muncar
# The weather API responded with:# 36 : Sedalia
# The weather API responded with:# 37 : Ancud
# The weather API responded with:# 38 : Souillac
# The weather API responded with:# 39 : Cabo San Lucas
# The weather API responded with:# 40 : Port Alfred
# The weather API responded with:# 41 : Berdigestyakh
# City Skipped: Data Missing
# The weather API responded with:# 42 : Nishihara
# The weather API responded with:# 43 : Puerto Ayora
# The weather API responded with:# 44 : Norman Wells
# City Skipped: Data Missing
# The weather API responded with:# 45 : Rehoboth
# The weather API responded with:# 46 : Ngunguru
# The weather API responded with:# 47 : Tuktoyaktuk
# The weather API responded with:# 48 : Provideniya
# The weather API responded with:# 49 : Bubaque
# City Skipped: Data Missing
# The weather API responded with:# 50 : Nzérékoré
# The weather API responded with:# 51 : Tiksi
# City Skipped: Data Missing
# The weather API responded with:# 52 : Caravelas
# The weather API responded with:# 53 : Hokitika
# The weather API responded with:# 54 : Bull Savanna
# The weather API responded with:# 55 : Bethel
# The weather API responded with:# 56 : Farafangana
# The weather API responded with:# 57 : Mahébourg
# The weather API responded with:# 58 : Pevek
# The weather API responded with:# 59 : Tahoua
# The weather API responded with:# 60 : Krasnosel'kup
# City Skipped: Data Missing
# The weather API responded with:# 61 : Carnarvon
# The weather API responded with:# 62 : Mackay
# The weather API responded with:# 63 : Ixtahuacán
# City Skipped: Data Missing
# The weather API responded with:# 64 : Kokopo
# The weather API responded with:# 65 : Lebu
# The weather API responded with:# 66 : Fairbanks
# City Skipped: Data Missing
# The weather API responded with:# 67 : Port Hawkesbury
# The weather API responded with:# 68 : Bambous Virieux
# The weather API responded with:# 69 : Saint Paul Harbor
# The weather API responded with:# 70 : Lagoa
# The weather API responded with:# 71 : Juazeiro
# The weather API responded with:# 72 : Susanville
# The weather API responded with:# 73 : Khatanga
# City Skipped: Data Missing
# The weather API responded with:# 74 : Saskylakh
# The weather API responded with:# 75 : Pisco
# The weather API responded with:# 76 : Vostok
# The weather API responded with:# 77 : Castro
# The weather API responded with:# 78 : Siilinjärvi
# The weather API responded with:# 79 : Alofi
# The weather API responded with:# 80 : Pārvatipuram
# The weather API responded with:# 81 : Mariehamn
# City Skipped: Data Missing
# The weather API responded with:# 82 : Bredasdorp
# The weather API responded with:# 83 : Port Hedland
# The weather API responded with:# 84 : Tuatapere
# The weather API responded with:# 85 : Nur
# The weather API responded with:# 86 : Port Keats
# The weather API responded with:# 87 : Fortuna
# The weather API responded with:# 88 : Faya
# The weather API responded with:# 89 : Psebay
# The weather API responded with:# 90 : São Filipe
# The weather API responded with:# 91 : Shimoda
# The weather API responded with:# 92 : Nortelândia
# The weather API responded with:# 93 : Padang
# The weather API responded with:# 94 : Zarubino
# The weather API responded with:# 95 : Sakakah
# The weather API responded with:# 96 : Les Escoumins
# The weather API responded with:# 97 : Ribeira Grande
# The weather API responded with:# 98 : Andenes
# The weather API responded with:# 99 : Dwārka
# The weather API responded with:# 100 : Port Elizabeth
# The weather API responded with:# 101 : Leningradskiy
# The weather API responded with:# 102 : Coahuayana Viejo
# City Skipped: Data Missing
# The weather API responded with:# 103 : Hithadhoo
# The weather API responded with:# 104 : Lüderitz
# The weather API responded with:# 105 : Cape Coast
# The weather API responded with:# 106 : Tasiilaq
# The weather API responded with:# 107 : Butaritari
# City Skipped: Data Missing
# The weather API responded with:# 108 : Kapaa
# The weather API responded with:# 109 : Kruisfontein
# The weather API responded with:# 110 : Hermanus
# City Skipped: Data Missing
# The weather API responded with:# 111 : Upernavik
# The weather API responded with:# 112 : La Libertad
# The weather API responded with:# 113 : Huicungo
# City Skipped: Data Missing
# The weather API responded with:# 114 : Innisfail
# The weather API responded with:# 115 : Collie
# The weather API responded with:# 116 : Guatire
# The weather API responded with:# 117 : Dudinka
# The weather API responded with:# 118 : Lewiston
# The weather API responded with:# 119 : Avarua
# The weather API responded with:# 120 : Tilichiki
# The weather API responded with:# 121 : Lavrentiya
# The weather API responded with:# 122 : Garoowe
# The weather API responded with:# 123 : Lata
# The weather API responded with:# 124 : Vitória
# The weather API responded with:# 125 : Vanimo
# The weather API responded with:# 126 : Haverfordwest
# The weather API responded with:# 127 : Bucerías
# The weather API responded with:# 128 : Alyangula
# The weather API responded with:# 129 : Wagar
# The weather API responded with:# 130 : Evanston
# The weather API responded with:# 131 : Cape Town
# The weather API responded with:# 132 : Portland
# The weather API responded with:# 133 : İzmit
# The weather API responded with:# 134 : Antofagasta
# The weather API responded with:# 135 : Busselton
# The weather API responded with:# 136 : Alice Springs
# The weather API responded with:# 137 : Katsuura
# The weather API responded with:# 138 : Stonewall
# The weather API responded with:# 139 : Dongli
# The weather API responded with:# 140 : Papara
# The weather API responded with:# 141 : Capelinha
# The weather API responded with:# 142 : Mar del Plata
# The weather API responded with:# 143 : Cedar Rapids
# The weather API responded with:# 144 : Todos Santos
# The weather API responded with:# 145 : Rāyagada
# City Skipped: Data Missing
# The weather API responded with:# 146 : Ithaca
# The weather API responded with:# 147 : Faanui
# The weather API responded with:# 148 : Baker City
# The weather API responded with:# 149 : Sur
# The weather API responded with:# 150 : Maltahöhe
# The weather API responded with:# 151 : Dikson
# The weather API responded with:# 152 : Korla
# The weather API responded with:# 153 : Elko
# The weather API responded with:# 154 : Severo-Kuril'sk
# The weather API responded with:# 155 : Nome
# The weather API responded with:# 156 : Asău
# The weather API responded with:# 157 : Mossamedes
# The weather API responded with:# 158 : Waddān
# The weather API responded with:# 159 : Pemangkat
# The weather API responded with:# 160 : Mayo
# The weather API responded with:# 161 : Lakhdenpokh'ya
# The weather API responded with:# 162 : Ndago
# The weather API responded with:# 163 : Illapel
# The weather API responded with:# 164 : Bereket
# The weather API responded with:# 165 : Shelburne
# The weather API responded with:# 166 : Sambava
# The weather API responded with:# 167 : Bhātāpāra
# The weather API responded with:# 168 : Binzhou
# The weather API responded with:# 169 : Teknāf
# The weather API responded with:# 170 : Ponta do Sol
# The weather API responded with:# 171 : Cidreira
# The weather API responded with:# 172 : Lipin Bor
# The weather API responded with:# 173 : Bergen
# The weather API responded with:# 174 : Koutiala
# The weather API responded with:# 175 : Nouadhibou
# City Skipped: Data Missing
# The weather API responded with:# 176 : Talnakh
# The weather API responded with:# 177 : Porbandar
# The weather API responded with:# 178 : Acaraú
# The weather API responded with:# 179 : Vidim
# The weather API responded with:# 180 : Ponta Delgada
# The weather API responded with:# 181 : Cayenne
# The weather API responded with:# 182 : Torbay
# The weather API responded with:# 183 : Port Macquarie
# The weather API responded with:# 184 : Shingū
# The weather API responded with:# 185 : Sitka
# The weather API responded with:# 186 : New Norfolk
# The weather API responded with:# 187 : Saldanha
# The weather API responded with:# 188 : Lorengau
# The weather API responded with:# 189 : Alakurtti
# The weather API responded with:# 190 : San Luis
# City Skipped: Data Missing
# The weather API responded with:# 191 : Hirara
# The weather API responded with:# 192 : Novska
# The weather API responded with:# 193 : Mangochi
# The weather API responded with:# 194 : George Town
# The weather API responded with:# 195 : Qaqortoq
# The weather API responded with:# 196 : Nizhniy Odes
# The weather API responded with:# 197 : Casa Grande
# The weather API responded with:# 198 : Margate
# The weather API responded with:# 199 : Half Moon Bay
# The weather API responded with:# 200 : Olinda
# The weather API responded with:# 201 : Toropets
# The weather API responded with:# 202 : Maumere
# The weather API responded with:# 203 : Aranos
# The weather API responded with:# 204 : Iskateley
# The weather API responded with:# 205 : Cockburn Town
# The weather API responded with:# 206 : Chui
# City Skipped: Data Missing
# The weather API responded with:# 207 : San Patricio
# The weather API responded with:# 208 : Utinga
# The weather API responded with:# 209 : Lisala
# The weather API responded with:# 210 : Kaabong
# The weather API responded with:# 211 : Talā
# The weather API responded with:# 212 : Nālūt
# The weather API responded with:# 213 : Arrondissement de Dieppe
# The weather API responded with:# 214 : Suntar
# The weather API responded with:# 215 : Chumphon
# The weather API responded with:# 216 : Salinópolis
# The weather API responded with:# 217 : Falun
# The weather API responded with:# 218 : Buraidah
# The weather API responded with:# 219 : Ambilobe
# The weather API responded with:# 220 : Hudiksvall
# The weather API responded with:# 221 : Grindavik
# The weather API responded with:# 222 : Moranbah
# The weather API responded with:# 223 : Jijiga
# The weather API responded with:# 224 : Moba
# The weather API responded with:# 225 : Khor
# The weather API responded with:# 226 : Lafia
# The weather API responded with:# 227 : Atasū
# The weather API responded with:# 228 : Jumla
# The weather API responded with:# 229 : Katherine
# The weather API responded with:# 230 : Srednekolymsk
# The weather API responded with:# 231 : Araouane
# The weather API responded with:# 232 : Oussouye
# The weather API responded with:# 233 : Dukat
# The weather API responded with:# 234 : Vazante
# The weather API responded with:# 235 : Husavik
# The weather API responded with:# 236 : Lima
# The weather API responded with:# 237 : Sherbakul'
# The weather API responded with:# 238 : Port Blair
# The weather API responded with:# 239 : Mapiripán
# The weather API responded with:# 240 : Thompson
# The weather API responded with:# 241 : Kiryat Gat
# The weather API responded with:# 242 : Smithers
# The weather API responded with:# 243 : Dunedin
# The weather API responded with:# 244 : Kumul
# City Skipped: Data Missing
# The weather API responded with:# 245 : Jhol
# The weather API responded with:# 246 : Ucluelet
# The weather API responded with:# 247 : Kungurtug
# The weather API responded with:# 248 : Inhambane
# The weather API responded with:# 249 : Palamós
# The weather API responded with:# 250 : Umluj
# The weather API responded with:# 251 : Guánica
# The weather API responded with:# 252 : Niğde
# The weather API responded with:# 253 : Ketchikan
# The weather API responded with:# 254 : Ducheng
# The weather API responded with:# 255 : Sayyan
# The weather API responded with:# 256 : Majene
# The weather API responded with:# 257 : Kununurra
# The weather API responded with:# 258 : Santa Lucía
# The weather API responded with:# 259 : Hualmay
# The weather API responded with:# 260 : Mirik
# The weather API responded with:# 261 : Menongue
# City Skipped: Data Missing
# The weather API responded with:# 262 : Nikolskoye
# The weather API responded with:# 263 : Takoradze
# The weather API responded with:# 264 : Mbengwi
# The weather API responded with:# 265 : Swan Hill
# The weather API responded with:# 266 : Aykhal
# The weather API responded with:# 267 : Paita
# The weather API responded with:# 268 : Hong Kong
# The weather API responded with:# 269 : Châlons-en-Champagne
# The weather API responded with:# 270 : Kaitangata
# The weather API responded with:# 271 : Kahului
# The weather API responded with:# 272 : Lazdijai
# The weather API responded with:# 273 : Hibaiyo
# The weather API responded with:# 274 : Agua Dulce
# The weather API responded with:# 275 : Nelson Bay
# The weather API responded with:# 276 : Okato
# City Skipped: Data Missing
# The weather API responded with:# 277 : Coquimbo
# The weather API responded with:# 278 : Longyearbyen
# City Skipped: Data Missing
# The weather API responded with:# 279 : Sibolga
# The weather API responded with:# 280 : Christchurch
# The weather API responded with:# 281 : Itoman
# The weather API responded with:# 282 : San Quintín
# City Skipped: Data Missing
# The weather API responded with:# 283 : Malbork
# The weather API responded with:# 284 : Nanortalik
# The weather API responded with:# 285 : Sola
# The weather API responded with:# 286 : Barrow
# The weather API responded with:# 287 : Biak
# The weather API responded with:# 288 : Vila
# The weather API responded with:# 289 : Caucaia
# The weather API responded with:# 290 : Lerwick
# The weather API responded with:# 291 : Malangali
# The weather API responded with:# 292 : Bang Krathum
# The weather API responded with:# 293 : Yulara
# The weather API responded with:# 294 : Broken Hill
# The weather API responded with:# 295 : Podosinovets
# The weather API responded with:# 296 : Tiznit Province
# The weather API responded with:# 297 : Yōkaichiba
# The weather API responded with:# 298 : Nabire
# The weather API responded with:# 299 : Airai
# The weather API responded with:# 300 : Marawi
# The weather API responded with:# 301 : Straumen
# The weather API responded with:# 302 : Storm Lake
# The weather API responded with:# 303 : Esim
# The weather API responded with:# 304 : Imbituba
# The weather API responded with:# 305 : Waingapu
# The weather API responded with:# 306 : Oktyabr'skiy
# The weather API responded with:# 307 : Cherskiy
# The weather API responded with:# 308 : Barbosa Ferraz
# City Skipped: Data Missing
# The weather API responded with:# 309 : Roald
# The weather API responded with:# 310 : Hobyo
# The weather API responded with:# 311 : Constitución
# City Skipped: Data Missing
# The weather API responded with:# 312 : Kirakira
# The weather API responded with:# 313 : San Cristobal
# The weather API responded with:# 314 : Jacareacanga
# The weather API responded with:# 315 : Ostrovnoy
# The weather API responded with:# 316 : Marsá Maţrūḩ
# The weather API responded with:# 317 : Wainwright
# The weather API responded with:# 318 : Adrar
# The weather API responded with:# 319 : Mount Gambier
# The weather API responded with:# 320 : Port Hardy
# The weather API responded with:# 321 : Esperance
# The weather API responded with:# 322 : Port-Gentil
# The weather API responded with:# 323 : Paamiut
# The weather API responded with:# 324 : Soteapan
# The weather API responded with:# 325 : Cao Bang
# The weather API responded with:# 326 : Praia
# City Skipped: Data Missing
# The weather API responded with:# 327 : Orhei
# The weather API responded with:# 328 : Port Moresby
# City Skipped: Data Missing
# The weather API responded with:# 329 : Badiraguato
# The weather API responded with:# 330 : Shakiso
# The weather API responded with:# 331 : Hornepayne
# The weather API responded with:# 332 : Santa Rosa
# The weather API responded with:# 333 : Marathon
# The weather API responded with:# 334 : North Platte
# The weather API responded with:# 335 : East Bethel
# The weather API responded with:# 336 : Santa Isabel Rio Negro
# The weather API responded with:# 337 : Hasaki
# The weather API responded with:# 338 : Tremedal
# The weather API responded with:# 339 : Rocha
# The weather API responded with:# 340 : Petropavlovsk-Kamchatskiy
# The weather API responded with:# 341 : Anáhuac
# The weather API responded with:# 342 : Westport
# City Skipped: Data Missing
# The weather API responded with:# 343 : Shediac
# The weather API responded with:# 344 : Bhādāsar
# The weather API responded with:# 345 : Rio Grande City
# The weather API responded with:# 346 : Avera
# The weather API responded with:# 347 : Muros
# City Skipped: Data Missing
# The weather API responded with:# 348 : Brzeg Dolny
# The weather API responded with:# 349 : Santa Inês
# The weather API responded with:# 350 : Huarmey
# The weather API responded with:# 351 : Elliot
# The weather API responded with:# 352 : Gao
# The weather API responded with:# 353 : Umm Kaddadah
# The weather API responded with:# 354 : Carballo
# The weather API responded with:# 355 : Kauhajoki
# The weather API responded with:# 356 : Namie
# City Skipped: Data Missing
# The weather API responded with:# 357 : Hay River
# The weather API responded with:# 358 : Hondomachi-hondo
# The weather API responded with:# 359 : Dinguiraye
# The weather API responded with:# 360 : Orlik
# The weather API responded with:# 361 : Sirte
# The weather API responded with:# 362 : Geraldton
# The weather API responded with:# 363 : Horsham
# The weather API responded with:# 364 : Litovko
# The weather API responded with:# 365 : Bay Roberts
# The weather API responded with:# 366 : Filimonovo
# The weather API responded with:# 367 : Bakchar
# The weather API responded with:# 368 : Kharhiāl
# The weather API responded with:# 369 : Carauari
# The weather API responded with:# 370 : Henties Bay
# The weather API responded with:# 371 : Kerema
# The weather API responded with:# 372 : Lubao
# The weather API responded with:# 373 : Ayan
# The weather API responded with:# 374 : Mehamn
# The weather API responded with:# 375 : Altay
# The weather API responded with:# 376 : Cabinda
# The weather API responded with:# 377 : Saint-Augustin
# The weather API responded with:# 378 : Iqaluit
# The weather API responded with:# 379 : Labuan
# The weather API responded with:# 380 : Panabá
# The weather API responded with:# 381 : Ulladulla
# The weather API responded with:# 382 : Nahrin
# The weather API responded with:# 383 : Saint-Pierre
# The weather API responded with:# 384 : Micheweni
# The weather API responded with:# 385 : Ürümqi
# The weather API responded with:# 386 : Cheyenne
# The weather API responded with:# 387 : Laurinburg
# The weather API responded with:# 388 : Baykit
# The weather API responded with:# 389 : Banjar
# The weather API responded with:# 390 : Zhaodong
# The weather API responded with:# 391 : Puerto Baquerizo Moreno
# The weather API responded with:# 392 : Makīnsk
# The weather API responded with:# 393 : Matara
# The weather API responded with:# 394 : LaBelle
# The weather API responded with:# 395 : Kudahuvadhoo
# The weather API responded with:# 396 : Lompoc
# The weather API responded with:# 397 : Bowen
# The weather API responded with:# 398 : Vao
# The weather API responded with:# 399 : Oban
# The weather API responded with:# 400 : Werda
# The weather API responded with:# 401 : Shenjiamen
# The weather API responded with:# 402 : Bichura
# The weather API responded with:# 403 : Yuanping
# The weather API responded with:# 404 : Sinnamary
# The weather API responded with:# 405 : Coyhaique
# The weather API responded with:# 406 : Malatya Province
# City Skipped: Data Missing
# City Skipped: Data Missing
# The weather API responded with:# 407 : Makakilo City
# The weather API responded with:# 408 : Guerrero Negro
# The weather API responded with:# 409 : Dingle
# The weather API responded with:# 410 : Yaan
# The weather API responded with:# 411 : Ternate
# The weather API responded with:# 412 : Santa Teresa del Tuy
# The weather API responded with:# 413 : Santa Cruz de la Sierra
# City Skipped: Data Missing
# The weather API responded with:# 414 : Rantepao
# The weather API responded with:# 415 : Cuamba
# The weather API responded with:# 416 : Slyudyanka
# The weather API responded with:# 417 : Dolores
# The weather API responded with:# 418 : Takāb
# The weather API responded with:# 419 : Lamu
# The weather API responded with:# 420 : Lahat
# The weather API responded with:# 421 : Tallahassee
# The weather API responded with:# 422 : Sombrerete
# The weather API responded with:# 423 : Kudat
# The weather API responded with:# 424 : Bengkulu
# The weather API responded with:# 425 : Nadym
# The weather API responded with:# 426 : Atar
# The weather API responded with:# 427 : Laguna
# The weather API responded with:# 428 : Wajima
# The weather API responded with:# 429 : Narsaq
# The weather API responded with:# 430 : Jhelum
# The weather API responded with:# 431 : Stolin
# The weather API responded with:# 432 : San Pedro del Pinatar
# The weather API responded with:# 433 : Santa Vitória
# The weather API responded with:# 434 : Fort Nelson
# The weather API responded with:# 435 : Bandar
# The weather API responded with:# 436 : Ozernovskiy
# The weather API responded with:# 437 : Kauswagan
# The weather API responded with:# 438 : Zapolyarnyy
# The weather API responded with:# 439 : Lakes Entrance
# The weather API responded with:# 440 : Pacific Grove
# The weather API responded with:# 441 : San Jose
# The weather API responded with:# 442 : Egvekinot
# The weather API responded with:# 443 : Gorontalo
# City Skipped: Data Missing
# The weather API responded with:# 444 : Buala
# The weather API responded with:# 445 : Taltal
# The weather API responded with:# 446 : Baculin
# The weather API responded with:# 447 : Jászberény
# The weather API responded with:# 448 : Lesosibirsk
# The weather API responded with:# 449 : Robertsport
# The weather API responded with:# 450 : Verkhnevilyuysk
# The weather API responded with:# 451 : Sept-Îles
# The weather API responded with:# 452 : Luangwa
# The weather API responded with:# 453 : Tabas
# The weather API responded with:# 454 : Yumen
# The weather API responded with:# 455 : Fussen
# The weather API responded with:# 456 : Harwich
# The weather API responded with:# 457 : Maraã
# The weather API responded with:# 458 : Te Anau
# The weather API responded with:# 459 : Bratsk
# The weather API responded with:# 460 : Orgtrud
# The weather API responded with:# 461 : Evensk
# The weather API responded with:# 462 : Biscarrosse
# City Skipped: Data Missing
# The weather API responded with:# 463 : Severobaykal'sk
# The weather API responded with:# 464 : Meulaboh
# The weather API responded with:# 465 : Canals
# The weather API responded with:# 466 : Ossora
# The weather API responded with:# 467 : Inyonga
# The weather API responded with:# 468 : Ipirá
# The weather API responded with:# 469 : Aksu
# The weather API responded with:# 470 : São João da Barra
# The weather API responded with:# 471 : Hofn
# The weather API responded with:# 472 : Walvis Bay
# The weather API responded with:# 473 : Carutapera
# The weather API responded with:# 474 : São Gabriel da Cachoeira
# The weather API responded with:# 475 : Zhangye
# The weather API responded with:# 476 : Dobson
# The weather API responded with:# 477 : Ambon City
# The weather API responded with:# 478 : Isangel
# The weather API responded with:# 479 : Cabra
# The weather API responded with:# 480 : Roebourne
# The weather API responded with:# 481 : Salalah
# City Skipped: Data Missing
# The weather API responded with:# 482 : Bungu
# The weather API responded with:# 483 : Vestmannaeyjar
# The weather API responded with:# 484 : Whyalla
# The weather API responded with:# 485 : Poum
# The weather API responded with:# 486 : Clarksburg
# The weather API responded with:# 487 : Paka
# The weather API responded with:# 488 : Kavieng
# The weather API responded with:# 489 : Vila Franca do Campo
# The weather API responded with:# 490 : Barra de Tecoanapa
# The weather API responded with:# 491 : Sisimiut
# The weather API responded with:# 492 : Serafimovich
# The weather API responded with:# 493 : Comodoro Rivadavia
# The weather API responded with:# 494 : Tautira
# The weather API responded with:# 495 : Inongo
# The weather API responded with:# 496 : Borogontsy
# The weather API responded with:# 497 : San Juan
# The weather API responded with:# 498 : Mujiayingzi
# The weather API responded with:# 499 : Mahanoro
# The weather API responded with:# 500 : Klaksvík
# The weather API responded with:# 501 : Stromness
# The weather API responded with:# 502 : Nishifukuma
# The weather API responded with:# 503 : Rovaniemi
# The weather API responded with:# 504 : Payo
# The weather API responded with:# 505 : Puerto Suárez
# The weather API responded with:# 506 : Durango
# The weather API responded with:# 507 : Shahdol
# The weather API responded with:# 508 : Bud
# City Skipped: Data Missing
# The weather API responded with:# 509 : Nouna
# The weather API responded with:# 510 : Riyadh
# The weather API responded with:# 511 : Maceió
# The weather API responded with:# 512 : Kanniyākumāri
# City Skipped: Data Missing
# The weather API responded with:# 513 : Jacmel
# The weather API responded with:# 514 : Palu
# The weather API responded with:# 515 : Kavaratti
# The weather API responded with:# 516 : Kharp
# The weather API responded with:# 517 : Bitung
# The weather API responded with:# 518 : Necochea
# The weather API responded with:# 519 : Dalby
# The weather API responded with:# 520 : Sārangarh
# The weather API responded with:# 521 : Saint George
# The weather API responded with:# 522 : Nador
# City Skipped: Data Missing
# City Skipped: Data Missing
# The weather API responded with:# 523 : Meadow Lake
# The weather API responded with:# 524 : Ilhabela
# The weather API responded with:# 525 : Muyezerskiy
# City Skipped: Data Missing
# The weather API responded with:# 526 : Tessalit
# The weather API responded with:# 527 : Annonay
# The weather API responded with:# 528 : Giżycko
# The weather API responded with:# 529 : Kalabo
# The weather API responded with:# 530 : Nyurba
# The weather API responded with:# 531 : Mareeba
# The weather API responded with:# 532 : Itacoatiara
# The weather API responded with:# 533 : Mersin Province
# City Skipped: Data Missing
# The weather API responded with:# 534 : Barinas
# The weather API responded with:# 535 : Okha
# The weather API responded with:# 536 : Severnoye
# The weather API responded with:# 537 : Karpogory
# The weather API responded with:# 538 : Tczew
# The weather API responded with:# 539 : Elwood
# The weather API responded with:# 540 : Hambantota
# The weather API responded with:# 541 : Aklavik
# The weather API responded with:# 542 : Marrakesh
# The weather API responded with:# 543 : Manuk Mangkaw
# The weather API responded with:# 544 : La Seyne-sur-Mer
# The weather API responded with:# 545 : Wu’an
# The weather API responded with:# 546 : Alkhan-Yurt
# The weather API responded with:# 547 : Springdale
# The weather API responded with:# 548 : San Antonio
# City Skipped: Data Missing
# The weather API responded with:# 549 : Belmonte
# The weather API responded with:# 550 : Macklin
# The weather API responded with:# 551 : Abu Samrah
# The weather API responded with:# 552 : Kasongo
# The weather API responded with:# 553 : Shahrud
# City Skipped: Data Missing
# The weather API responded with:# 554 : Taoudenni
# City Skipped: Data Missing
# The weather API responded with:# 555 : Balkhash
# The weather API responded with:# 556 : Havelock
# The weather API responded with:# 557 : Uray
# City Skipped: Data Missing
# The weather API responded with:# 558 : Mogadishu
# The weather API responded with:# 559 : Pochutla
# The weather API responded with:# 560 : Aparecida do Taboado
# City Skipped: Data Missing
# The weather API responded with:# 561 : Saint Augustine
# The weather API responded with:# 562 : Arroyo de la Encomienda
# The weather API responded with:# 563 : Suluova
# The weather API responded with:# 564 : Broome
# The weather API responded with:# 565 : Vernon
# The weather API responded with:# 566 : Chernyshevskiy
# The weather API responded with:# 567 : Santa Luzia
# The weather API responded with:# 568 : Mayor Pablo Lagerenza
# The weather API responded with:# 569 : Deputatsky
# The weather API responded with:# 570 : Igarka
# The weather API responded with:# 571 : Namatanai
# The weather API responded with:# 572 : Aykino
# The weather API responded with:# 573 : Hastings
# City Skipped: Data Missing
# The weather API responded with:# 574 : Gushikawa
# The weather API responded with:# 575 : Springfield
# The weather API responded with:# 576 : San Ignacio Río Muerto
# The weather API responded with:# 577 : Bairiki Village
# The weather API responded with:# 578 : Senanga
# The weather API responded with:# 579 : Los Llanos de Aridane
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create Dictionary of data with column names
city_weather = {"City": cities, "Country": country,
               "Cloudiness %": cloudiness, "Humidity": humidity,
               "Date": date, "Max Temp (F)": max_temp,
               "Wind Speed (mph)": wind_speed, "Latitude": lat,
               "Longitude": lng}

weather_data = pd.DataFrame.from_dict(city_weather, orient='index')

# Switch row and columns titles
weather_data = weather_data.transpose()

# Dropping records with no data
weather_data.dropna(inplace=True)
weather_data

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
